# %%
import json
import spacy
import gensim
from nltk.tokenize import sent_tokenize, wordpunct_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from tqdm import tqdm
import pandas as pd
import os
import re
from string import punctuation
import gensim
import logging
import urllib.request

import warnings
warnings.filterwarnings('ignore')
# На вход модели даем текстовый файл, каждое предложение на отдельной строчке.

# %%
re_character = re.compile(r'(.+?):')
re_text = re.compile(r': (.+)')
re_episode = re.compile(r'(\w+?)\.')
re_del = re.compile(r'\[.+?\]')

# %%
def define_character(lines, file):
    character_texts = []
    episode = re_episode.match(file)[1]
    for n, line in enumerate(lines):
        line = re_del.sub('', line)
        if re_character.match(line) and re_text.search(line):
            character = re_character.match(line)[1]
            text = re_text.search(line)[1]
            character_texts.append(
                {'character': character, 
                 'episode': episode, 
                 'line': text}
            )
    return character_texts

# %%
characters_table = pd.DataFrame(columns=['character', 'episode', 'line'])
for root, dirs, files in os.walk('./SpongeBob_SquarePants_Transcripts'):
    for file in tqdm(files):
        path = os.path.join(root, file)
        with open(path, 'r', encoding='utf-8') as f:
            lines = f.readlines()
        character_texts = define_character(lines, file)
        characters_table = characters_table.append(character_texts, ignore_index=True)

# %%
my_characters = characters_table[characters_table['character'].copy().isin([
    'SpongeBob', 'Patrick', 'Mr. Krabs', 'Squidward', 'Plankton', 'Sandy', 'Karen'])]

# %%
sw = stopwords.words('english')
lemmatizer = WordNetLemmatizer()
nltk_to_pos = {'ADV': 'r', 'NOUN': 'n', 'VERB': 'v', 'ADJ': 'a'}

# %%
def for_model(line):
    lemmas = []
    new_sent = []
    sentences = sent_tokenize(line)
    for sent in sentences:
        words = [word for word in word_tokenize(sent) if word[-1] not in punctuation]
        if words != []:
            new_sent.append(' '.join(words))
        lemmas = []
    return '\n'.join(new_sent)
'''
def for_model(line):
    lemmas = []
    new_sent = []
    sentences = sent_tokenize(line)
    for sent in sentences:
        words = [word for word in word_tokenize(sent) if word[-1] not in punctuation]
        for word in words:
            pos = pos_tag([word], tagset='universal')[0][1]
            if pos in ['VERB', 'NOUN', 'ADV', 'ADJ']:
                word = lemmatizer.lemmatize(word.lower(), pos=nltk_to_pos[pos])
            else:
                word = lemmatizer.lemmatize(word.lower())
            lemmas.append(word)
        if lemmas != []:
            new_sent.append(' '.join(lemmas))
        lemmas = []
    return '\n'.join(new_sent)
'''
# Out:
# "\ndef for_model(line):\n    lemmas = []\n    new_sent = []\n    sentences = sent_tokenize(line)\n    for sent in sentences:\n        words = [word for word in word_tokenize(sent) if word[-1] not in punctuation]\n        for word in words:\n            pos = pos_tag([word], tagset='universal')[0][1]\n            if pos in ['VERB', 'NOUN', 'ADV', 'ADJ']:\n                word = lemmatizer.lemmatize(word.lower(), pos=nltk_to_pos[pos])\n            else:\n                word = lemmatizer.lemmatize(word.lower())\n            lemmas.append(word)\n        if lemmas != []:\n            new_sent.append(' '.join(lemmas))\n        lemmas = []\n    return '\n'.join(new_sent)\n"

# %%
my_characters['lemmatized_lines'] = my_characters['line'].apply(for_model)

# %%
my_characters.head()
# Out:
#    character          episode  \
# 1  SpongeBob  LighthouseLouie
# 4  SpongeBob  LighthouseLouie
# 5  SpongeBob  LighthouseLouie
# 7  SpongeBob  LighthouseLouie
# 9  SpongeBob  LighthouseLouie
#
#                                                 line  \
# 1   Hold on, I'll check the textbook.  Ah, "Your ...
# 4                                            Hooray!
# 5   Mrs. Puff! Oh, there you are.  I'll make it u...
# 7                                   I love cleaning!
# 9   That takes care of that.  Yuck. This place ne...
#
#                                     lemmatized_lines
# 1  Hold on I 'll check the textbook\nAh Your Mirr...
# 4                                             Hooray
# 5  Mrs\nPuff\nOh there you are\nI 'll make it up ...
# 7                                    I love cleaning
# 9  That takes care of that\nYuck\nThis place need...

# %%
all_lines = my_characters.groupby('character')['lemmatized_lines'].agg(list).reset_index()

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
i = -1
for name in all_lines['character'].unique():
    i += 1
    with open(f'{name}.txt', 'w') as f:
        f.write('\n'.join(all_lines[all_lines['character'] == name]['lemmatized_lines'][i]))

# %%
models = {}
for name in all_lines['character'].unique():
    text = f'{name}.txt'
    data = gensim.models.word2vec.LineSentence(text)
    model_char = gensim.models.Word2Vec(data, vector_size=300, window=5, min_count=2)
    models[name] = model_char
    model_char.init_sims(replace=True)
    model_path = f'{name}.bin'
    model_char.wv.save_word2vec_format(model_path, binary=True)
# Out:
# 2022-03-24 22:38:56,047 : INFO : collecting all words and their counts
# 2022-03-24 22:38:56,049 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-03-24 22:38:56,055 : INFO : collected 1203 word types from a corpus of 3935 raw words and 638 sentences
# 2022-03-24 22:38:56,056 : INFO : Creating a fresh vocabulary
# 2022-03-24 22:38:56,060 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 retains 408 unique words (33.915211970074814%% of original 1203, drops 795)', 'datetime': '2022-03-24T22:38:56.060619', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:56,061 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 3140 word corpus (79.79669631512071%% of original 3935, drops 795)', 'datetime': '2022-03-24T22:38:56.061866', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:56,065 : INFO : deleting the raw counts dictionary of 1203 items
# 2022-03-24 22:38:56,066 : INFO : sample=0.001 downsamples 80 most-common words
# 2022-03-24 22:38:56,067 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 2025.5226759533073 word corpus (64.5%% of prior 3140)', 'datetime': '2022-03-24T22:38:56.067514', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:56,074 : INFO : estimated required memory for 408 words and 300 dimensions: 1183200 bytes
# 2022-03-24 22:38:56,075 : INFO : resetting layer weights
# 2022-03-24 22:38:56,078 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-03-24T22:38:56.078023', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2022-03-24 22:38:56,078 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 408 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-03-24T22:38:56.078735', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 2022-03-24 22:38:56,088 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,089 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,093 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,093 : INFO : EPOCH - 1 : training on 3935 raw words (1957 effective words) took 0.0s, 206121 effective words/s
# 2022-03-24 22:38:56,099 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,100 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,104 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,104 : INFO : EPOCH - 2 : training on 3935 raw words (2012 effective words) took 0.0s, 226855 effective words/s
# 2022-03-24 22:38:56,109 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,110 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,113 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,113 : INFO : EPOCH - 3 : training on 3935 raw words (2032 effective words) took 0.0s, 282744 effective words/s
# 2022-03-24 22:38:56,118 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,118 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,121 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,122 : INFO : EPOCH - 4 : training on 3935 raw words (2057 effective words) took 0.0s, 312120 effective words/s
# 2022-03-24 22:38:56,125 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,126 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,128 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,129 : INFO : EPOCH - 5 : training on 3935 raw words (2037 effective words) took 0.0s, 340825 effective words/s
# 2022-03-24 22:38:56,129 : INFO : Word2Vec lifecycle event {'msg': 'training on 19675 raw words (10095 effective words) took 0.1s, 200551 effective words/s', 'datetime': '2022-03-24T22:38:56.129634', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 2022-03-24 22:38:56,130 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec(vocab=408, vector_size=300, alpha=0.025)', 'datetime': '2022-03-24T22:38:56.130119', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}
# 2022-03-24 22:38:56,130 : WARNING : destructive init_sims(replace=True) deprecated & no longer required for space-efficiency
# 2022-03-24 22:38:56,131 : INFO : storing 408x300 projection weights into Karen.bin
# 2022-03-24 22:38:56,134 : INFO : collecting all words and their counts
# 2022-03-24 22:38:56,135 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-03-24 22:38:56,157 : INFO : collected 6509 word types from a corpus of 58656 raw words and 9875 sentences
# 2022-03-24 22:38:56,158 : INFO : Creating a fresh vocabulary
# 2022-03-24 22:38:56,166 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 retains 2890 unique words (44.40006145337225%% of original 6509, drops 3619)', 'datetime': '2022-03-24T22:38:56.166580', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:56,167 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 55037 word corpus (93.8301282051282%% of original 58656, drops 3619)', 'datetime': '2022-03-24T22:38:56.167199', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:56,178 : INFO : deleting the raw counts dictionary of 6509 items
# 2022-03-24 22:38:56,179 : INFO : sample=0.001 downsamples 67 most-common words
# 2022-03-24 22:38:56,179 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 40428.31817854932 word corpus (73.5%% of prior 55037)', 'datetime': '2022-03-24T22:38:56.179911', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:56,201 : INFO : estimated required memory for 2890 words and 300 dimensions: 8381000 bytes
# 2022-03-24 22:38:56,202 : INFO : resetting layer weights
# 2022-03-24 22:38:56,207 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-03-24T22:38:56.207614', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2022-03-24 22:38:56,208 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 2890 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-03-24T22:38:56.208075', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 2022-03-24 22:38:56,256 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,260 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,260 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,261 : INFO : EPOCH - 1 : training on 58656 raw words (40479 effective words) took 0.1s, 779670 effective words/s
# 2022-03-24 22:38:56,307 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,311 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,312 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,313 : INFO : EPOCH - 2 : training on 58656 raw words (40329 effective words) took 0.0s, 1113734 effective words/s
# 2022-03-24 22:38:56,358 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,362 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,362 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,363 : INFO : EPOCH - 3 : training on 58656 raw words (40399 effective words) took 0.0s, 833154 effective words/s
# 2022-03-24 22:38:56,407 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,411 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,412 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,412 : INFO : EPOCH - 4 : training on 58656 raw words (40395 effective words) took 0.0s, 833353 effective words/s
# 2022-03-24 22:38:56,638 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,641 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,641 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,642 : INFO : EPOCH - 5 : training on 58656 raw words (40524 effective words) took 0.2s, 177336 effective words/s
# 2022-03-24 22:38:56,642 : INFO : Word2Vec lifecycle event {'msg': 'training on 293280 raw words (202126 effective words) took 0.4s, 465598 effective words/s', 'datetime': '2022-03-24T22:38:56.642480', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 2022-03-24 22:38:56,642 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec(vocab=2890, vector_size=300, alpha=0.025)', 'datetime': '2022-03-24T22:38:56.642801', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}
# 2022-03-24 22:38:56,644 : WARNING : destructive init_sims(replace=True) deprecated & no longer required for space-efficiency
# 2022-03-24 22:38:56,646 : INFO : storing 2890x300 projection weights into Mr. Krabs.bin
# 2022-03-24 22:38:56,657 : INFO : collecting all words and their counts
# 2022-03-24 22:38:56,658 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-03-24 22:38:56,679 : INFO : collected 5154 word types from a corpus of 42856 raw words and 9013 sentences
# 2022-03-24 22:38:56,679 : INFO : Creating a fresh vocabulary
# 2022-03-24 22:38:56,686 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 retains 2277 unique words (44.17927823050058%% of original 5154, drops 2877)', 'datetime': '2022-03-24T22:38:56.686010', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:56,686 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 39979 word corpus (93.28682098189284%% of original 42856, drops 2877)', 'datetime': '2022-03-24T22:38:56.686465', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:56,695 : INFO : deleting the raw counts dictionary of 5154 items
# 2022-03-24 22:38:56,695 : INFO : sample=0.001 downsamples 68 most-common words
# 2022-03-24 22:38:56,695 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 28874.274475853734 word corpus (72.2%% of prior 39979)', 'datetime': '2022-03-24T22:38:56.695959', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:56,713 : INFO : estimated required memory for 2277 words and 300 dimensions: 6603300 bytes
# 2022-03-24 22:38:56,713 : INFO : resetting layer weights
# 2022-03-24 22:38:56,717 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-03-24T22:38:56.717427', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2022-03-24 22:38:56,717 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 2277 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-03-24T22:38:56.717889', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 2022-03-24 22:38:56,757 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,758 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,758 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,758 : INFO : EPOCH - 1 : training on 42856 raw words (28736 effective words) took 0.0s, 724275 effective words/s
# 2022-03-24 22:38:56,794 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,797 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,801 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,801 : INFO : EPOCH - 2 : training on 42856 raw words (28883 effective words) took 0.0s, 691674 effective words/s
# 2022-03-24 22:38:56,837 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,839 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,843 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,844 : INFO : EPOCH - 3 : training on 42856 raw words (28800 effective words) took 0.0s, 701356 effective words/s
# 2022-03-24 22:38:56,879 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,882 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,886 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,887 : INFO : EPOCH - 4 : training on 42856 raw words (28843 effective words) took 0.0s, 689294 effective words/s
# 2022-03-24 22:38:56,922 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:56,925 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:56,930 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:56,930 : INFO : EPOCH - 5 : training on 42856 raw words (28814 effective words) took 0.0s, 679473 effective words/s
# 2022-03-24 22:38:56,931 : INFO : Word2Vec lifecycle event {'msg': 'training on 214280 raw words (144076 effective words) took 0.2s, 676769 effective words/s', 'datetime': '2022-03-24T22:38:56.931077', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 2022-03-24 22:38:56,931 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec(vocab=2277, vector_size=300, alpha=0.025)', 'datetime': '2022-03-24T22:38:56.931399', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}
# 2022-03-24 22:38:56,932 : WARNING : destructive init_sims(replace=True) deprecated & no longer required for space-efficiency
# 2022-03-24 22:38:56,934 : INFO : storing 2277x300 projection weights into Patrick.bin
# 2022-03-24 22:38:56,943 : INFO : collecting all words and their counts
# 2022-03-24 22:38:56,944 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-03-24 22:38:56,954 : INFO : collected 4015 word types from a corpus of 25429 raw words and 4397 sentences
# 2022-03-24 22:38:56,955 : INFO : Creating a fresh vocabulary
# 2022-03-24 22:38:56,959 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 retains 1630 unique words (40.59775840597759%% of original 4015, drops 2385)', 'datetime': '2022-03-24T22:38:56.959854', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:56,960 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 23044 word corpus (90.62094459082151%% of original 25429, drops 2385)', 'datetime': '2022-03-24T22:38:56.960362', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:56,966 : INFO : deleting the raw counts dictionary of 4015 items
# 2022-03-24 22:38:56,967 : INFO : sample=0.001 downsamples 69 most-common words
# 2022-03-24 22:38:56,967 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 16547.18114058354 word corpus (71.8%% of prior 23044)', 'datetime': '2022-03-24T22:38:56.967765', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:56,980 : INFO : estimated required memory for 1630 words and 300 dimensions: 4727000 bytes
# 2022-03-24 22:38:56,981 : INFO : resetting layer weights
# 2022-03-24 22:38:56,983 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-03-24T22:38:56.983592', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2022-03-24 22:38:56,983 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 1630 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-03-24T22:38:56.983902', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 2022-03-24 22:38:57,002 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:57,005 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:57,008 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:57,009 : INFO : EPOCH - 1 : training on 25429 raw words (16464 effective words) took 0.0s, 689612 effective words/s
# 2022-03-24 22:38:57,029 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:57,031 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:57,034 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:57,034 : INFO : EPOCH - 2 : training on 25429 raw words (16620 effective words) took 0.0s, 685799 effective words/s
# 2022-03-24 22:38:57,056 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:57,057 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:57,060 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:57,060 : INFO : EPOCH - 3 : training on 25429 raw words (16645 effective words) took 0.0s, 670593 effective words/s
# 2022-03-24 22:38:57,081 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:57,082 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:57,085 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:57,085 : INFO : EPOCH - 4 : training on 25429 raw words (16541 effective words) took 0.0s, 705315 effective words/s
# 2022-03-24 22:38:57,105 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:57,106 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:57,109 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:57,109 : INFO : EPOCH - 5 : training on 25429 raw words (16543 effective words) took 0.0s, 713523 effective words/s
# 2022-03-24 22:38:57,110 : INFO : Word2Vec lifecycle event {'msg': 'training on 127145 raw words (82813 effective words) took 0.1s, 657965 effective words/s', 'datetime': '2022-03-24T22:38:57.110115', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 2022-03-24 22:38:57,110 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec(vocab=1630, vector_size=300, alpha=0.025)', 'datetime': '2022-03-24T22:38:57.110365', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}
# 2022-03-24 22:38:57,111 : WARNING : destructive init_sims(replace=True) deprecated & no longer required for space-efficiency
# 2022-03-24 22:38:57,112 : INFO : storing 1630x300 projection weights into Plankton.bin
# 2022-03-24 22:38:57,120 : INFO : collecting all words and their counts
# 2022-03-24 22:38:57,120 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-03-24 22:38:57,127 : INFO : collected 3247 word types from a corpus of 17040 raw words and 2795 sentences
# 2022-03-24 22:38:57,128 : INFO : Creating a fresh vocabulary
# 2022-03-24 22:38:57,131 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 retains 1301 unique words (40.06775485063135%% of original 3247, drops 1946)', 'datetime': '2022-03-24T22:38:57.131955', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:57,132 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 15094 word corpus (88.57981220657277%% of original 17040, drops 1946)', 'datetime': '2022-03-24T22:38:57.132464', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:57,137 : INFO : deleting the raw counts dictionary of 3247 items
# 2022-03-24 22:38:57,138 : INFO : sample=0.001 downsamples 71 most-common words
# 2022-03-24 22:38:57,138 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 10736.431619972265 word corpus (71.1%% of prior 15094)', 'datetime': '2022-03-24T22:38:57.138454', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:57,148 : INFO : estimated required memory for 1301 words and 300 dimensions: 3772900 bytes
# 2022-03-24 22:38:57,149 : INFO : resetting layer weights
# 2022-03-24 22:38:57,151 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-03-24T22:38:57.151858', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2022-03-24 22:38:57,152 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 1301 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-03-24T22:38:57.152164', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 2022-03-24 22:38:57,160 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:57,169 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:57,170 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:57,170 : INFO : EPOCH - 1 : training on 17040 raw words (10702 effective words) took 0.0s, 610219 effective words/s
# 2022-03-24 22:38:57,179 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:57,188 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:57,189 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:57,189 : INFO : EPOCH - 2 : training on 17040 raw words (10690 effective words) took 0.0s, 605549 effective words/s
# 2022-03-24 22:38:57,198 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:57,206 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:57,208 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:57,208 : INFO : EPOCH - 3 : training on 17040 raw words (10783 effective words) took 0.0s, 627242 effective words/s
# 2022-03-24 22:38:57,216 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:57,225 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:57,226 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:57,226 : INFO : EPOCH - 4 : training on 17040 raw words (10787 effective words) took 0.0s, 618394 effective words/s
# 2022-03-24 22:38:57,235 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:57,244 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:57,245 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:57,245 : INFO : EPOCH - 5 : training on 17040 raw words (10748 effective words) took 0.0s, 618422 effective words/s
# 2022-03-24 22:38:57,246 : INFO : Word2Vec lifecycle event {'msg': 'training on 85200 raw words (53710 effective words) took 0.1s, 573159 effective words/s', 'datetime': '2022-03-24T22:38:57.246199', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 2022-03-24 22:38:57,246 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec(vocab=1301, vector_size=300, alpha=0.025)', 'datetime': '2022-03-24T22:38:57.246539', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}
# 2022-03-24 22:38:57,247 : WARNING : destructive init_sims(replace=True) deprecated & no longer required for space-efficiency
# 2022-03-24 22:38:57,248 : INFO : storing 1301x300 projection weights into Sandy.bin
# 2022-03-24 22:38:57,255 : INFO : collecting all words and their counts
# 2022-03-24 22:38:57,255 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-03-24 22:38:57,278 : INFO : PROGRESS: at sentence #10000, processed 53909 words, keeping 5949 word types
# 2022-03-24 22:38:57,299 : INFO : PROGRESS: at sentence #20000, processed 107806 words, keeping 8877 word types
# 2022-03-24 22:38:57,314 : INFO : collected 10790 word types from a corpus of 147134 raw words and 27193 sentences
# 2022-03-24 22:38:57,315 : INFO : Creating a fresh vocabulary
# 2022-03-24 22:38:57,329 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 retains 5011 unique words (46.44114921223355%% of original 10790, drops 5779)', 'datetime': '2022-03-24T22:38:57.329016', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:57,329 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 141355 word corpus (96.0722878464529%% of original 147134, drops 5779)', 'datetime': '2022-03-24T22:38:57.329588', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:57,348 : INFO : deleting the raw counts dictionary of 10790 items
# 2022-03-24 22:38:57,349 : INFO : sample=0.001 downsamples 70 most-common words
# 2022-03-24 22:38:57,349 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 105223.64581232138 word corpus (74.4%% of prior 141355)', 'datetime': '2022-03-24T22:38:57.349639', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:57,386 : INFO : estimated required memory for 5011 words and 300 dimensions: 14531900 bytes
# 2022-03-24 22:38:57,387 : INFO : resetting layer weights
# 2022-03-24 22:38:57,393 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-03-24T22:38:57.393563', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2022-03-24 22:38:57,393 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 5011 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-03-24T22:38:57.393874', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 2022-03-24 22:38:57,509 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:57,516 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:57,517 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:57,517 : INFO : EPOCH - 1 : training on 147134 raw words (105288 effective words) took 0.1s, 858942 effective words/s
# 2022-03-24 22:38:57,633 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:57,635 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:57,639 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:57,640 : INFO : EPOCH - 2 : training on 147134 raw words (105162 effective words) took 0.1s, 866509 effective words/s
# 2022-03-24 22:38:57,753 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:57,758 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:57,760 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:57,760 : INFO : EPOCH - 3 : training on 147134 raw words (105491 effective words) took 0.1s, 887238 effective words/s
# 2022-03-24 22:38:57,957 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:57,959 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:57,963 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:57,963 : INFO : EPOCH - 4 : training on 147134 raw words (105266 effective words) took 0.2s, 519780 effective words/s
# 2022-03-24 22:38:58,075 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:58,078 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:58,078 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:58,078 : INFO : EPOCH - 5 : training on 147134 raw words (105289 effective words) took 0.1s, 926896 effective words/s
# 2022-03-24 22:38:58,078 : INFO : Word2Vec lifecycle event {'msg': 'training on 735670 raw words (526496 effective words) took 0.7s, 768828 effective words/s', 'datetime': '2022-03-24T22:38:58.078887', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 2022-03-24 22:38:58,079 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec(vocab=5011, vector_size=300, alpha=0.025)', 'datetime': '2022-03-24T22:38:58.079243', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}
# 2022-03-24 22:38:58,081 : WARNING : destructive init_sims(replace=True) deprecated & no longer required for space-efficiency
# 2022-03-24 22:38:58,084 : INFO : storing 5011x300 projection weights into SpongeBob.bin
# 2022-03-24 22:38:58,103 : INFO : collecting all words and their counts
# 2022-03-24 22:38:58,104 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2022-03-24 22:38:58,122 : INFO : collected 5474 word types from a corpus of 46539 raw words and 8432 sentences
# 2022-03-24 22:38:58,123 : INFO : Creating a fresh vocabulary
# 2022-03-24 22:38:58,129 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 retains 2385 unique words (43.569601753744976%% of original 5474, drops 3089)', 'datetime': '2022-03-24T22:38:58.129897', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:58,130 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=2 leaves 43450 word corpus (93.36255613571413%% of original 46539, drops 3089)', 'datetime': '2022-03-24T22:38:58.130402', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:58,139 : INFO : deleting the raw counts dictionary of 5474 items
# 2022-03-24 22:38:58,140 : INFO : sample=0.001 downsamples 67 most-common words
# 2022-03-24 22:38:58,140 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 31197.315017150588 word corpus (71.8%% of prior 43450)', 'datetime': '2022-03-24T22:38:58.140387', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'prepare_vocab'}
# 2022-03-24 22:38:58,158 : INFO : estimated required memory for 2385 words and 300 dimensions: 6916500 bytes
# 2022-03-24 22:38:58,158 : INFO : resetting layer weights
# 2022-03-24 22:38:58,162 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-03-24T22:38:58.162298', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'build_vocab'}
# 2022-03-24 22:38:58,162 : INFO : Word2Vec lifecycle event {'msg': 'training model with 3 workers on 2385 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2022-03-24T22:38:58.162775', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 2022-03-24 22:38:58,197 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:58,204 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:58,204 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:58,205 : INFO : EPOCH - 1 : training on 46539 raw words (31193 effective words) took 0.0s, 765729 effective words/s
# 2022-03-24 22:38:58,240 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:58,246 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:58,247 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:58,247 : INFO : EPOCH - 2 : training on 46539 raw words (31186 effective words) took 0.0s, 757236 effective words/s
# 2022-03-24 22:38:58,282 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:58,288 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:58,288 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:58,289 : INFO : EPOCH - 3 : training on 46539 raw words (31270 effective words) took 0.0s, 771087 effective words/s
# 2022-03-24 22:38:58,324 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:58,331 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:58,331 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:58,331 : INFO : EPOCH - 4 : training on 46539 raw words (31218 effective words) took 0.0s, 765417 effective words/s
# 2022-03-24 22:38:58,365 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2022-03-24 22:38:58,372 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2022-03-24 22:38:58,373 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2022-03-24 22:38:58,373 : INFO : EPOCH - 5 : training on 46539 raw words (31276 effective words) took 0.0s, 1363083 effective words/s
# 2022-03-24 22:38:58,373 : INFO : Word2Vec lifecycle event {'msg': 'training on 232695 raw words (156143 effective words) took 0.2s, 742062 effective words/s', 'datetime': '2022-03-24T22:38:58.373647', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'train'}
# 2022-03-24 22:38:58,373 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec(vocab=2385, vector_size=300, alpha=0.025)', 'datetime': '2022-03-24T22:38:58.373926', 'gensim': '4.1.2', 'python': '3.9.6 (v3.9.6:db3ff76da1, Jun 28 2021, 11:49:53) \n[Clang 6.0 (clang-600.0.57)]', 'platform': 'macOS-10.16-x86_64-i386-64bit', 'event': 'created'}
# 2022-03-24 22:38:58,375 : WARNING : destructive init_sims(replace=True) deprecated & no longer required for space-efficiency
# 2022-03-24 22:38:58,376 : INFO : storing 2385x300 projection weights into Squidward.bin

# %%
models
# Out:
# {'Karen': <gensim.models.word2vec.Word2Vec at 0x7fb9f5c7bbe0>,
#  'Mr. Krabs': <gensim.models.word2vec.Word2Vec at 0x7fb9f5c7b310>,
#  'Patrick': <gensim.models.word2vec.Word2Vec at 0x7fba01b5d430>,
#  'Plankton': <gensim.models.word2vec.Word2Vec at 0x7fb9f5969130>,
#  'Sandy': <gensim.models.word2vec.Word2Vec at 0x7fba00c5cbb0>,
#  'SpongeBob': <gensim.models.word2vec.Word2Vec at 0x7fb9f5c7b7c0>,
#  'Squidward': <gensim.models.word2vec.Word2Vec at 0x7fba01879af0>}

# %%
models['SpongeBob'].wv.most_similar('Karen')
# Out:
# [("'em", 0.9076336622238159),
#  ('inside', 0.9076310992240906),
#  ('before', 0.9073677062988281),
#  ('Nutty', 0.9069185256958008),
#  ('ice', 0.9067336916923523),
#  ('That', 0.9065715074539185),
#  ('moon', 0.9065337181091309),
#  ('Bottom', 0.9065083861351013),
#  ('them', 0.9062583446502686),
#  ("n't", 0.9061850309371948)]
